# %% [markdown]
# # K-Means Clustering

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
X, y = make_blobs(n_samples=200, centers=2, cluster_std=0.40, random_state=0)
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# # #Within-Cluster-Sum-of-Squares (WCSS)

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Dr.PVVK\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# class sklearn.cluster.KMeans(n_clusters=8, *, init='k-means++', n_init=10, max_iter=300, tol=0.0001, precompute_distances='deprecated', verbose=0, random_state=None, copy_x=True, n_jobs='deprecated', algorithm='auto')

# %% [markdown]
# ‘k-means++’ : selects initial cluster centers for k-mean clustering in a smart way to speed up convergence. See section Notes in k_init for more details.

# %% [markdown]
# max_iterint, default=300
# Maximum number of iterations of the k-means algorithm to run.

# %% [markdown]
# n_initint, default=10
# Number of time the k-means algorithm will be run with different centroid seeds. The final results will be the best output of n_init consecutive runs in terms of inertia.

# %%
plt.plot(range(1, 20), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=30, verbose=True, n_init=10, random_state=0)

# %%
pred_y = kmeans.fit_predict(X)
# Out:
# Initialization complete
# Iteration 0, inertia 112.11954347760341
# Iteration 1, inertia 60.591129306174665
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 84.189116084297
# Iteration 1, inertia 60.591129306174665
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 135.80162888495866
# Iteration 1, inertia 60.591129306174665
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 87.91455596837162
# Iteration 1, inertia 60.591129306174665
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 64.38343338955265
# Iteration 1, inertia 60.591129306174665
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 80.56675223074377
# Iteration 1, inertia 60.591129306174665
# Converged at iteration 1: strict convergence.
# Initialization complete
# ...

# %%
plt.scatter(X[:,0], X[:,1])
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=30, c='red')
plt.show()
